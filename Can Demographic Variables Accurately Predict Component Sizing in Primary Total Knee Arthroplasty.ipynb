# %% [markdown]
# # Background
# As health care reform drives providers to reduce costs and improve efficiencies without
# compromising patient care, preoperative planning has become imperative. The purpose of this study is to
# determine whether height, weight, and gender can accurately predict total knee arthroplasty (TKA)
# sizing.

# %% [markdown]
# Preoperative templating in total knee arthroplasty (TKA) provides surgeons the ability to anticipate final implant size and prepare for potential intraoperative difficulties or roadblocks that may
# occur along the way, such as severe deformity correction and the
# need for special equipment or nonstandard implants [1e3]. Accurate templating has become essential for surgical planning, particularly in community or outpatient settings where resources are
# more limited. Inaccurate or poor preoperative planning may result
# in the absence of the most appropriate implant for the patient at the
# time of surgery. This carries substantial morbidity and economic
# burden, and minimizing such scenarios is essential [4,5].
# As we enter the new era of value-based health care, delivery of
# patient care in an accurate and affordable manner will prove
# paramount [6,7]. Traditional templating methods have demonstrated variable degrees of accuracy in regard to predicting final
# implant size and re-establishing coronal alignment, resulting in a
# push toward more reliable but potentially more costly and
# time-involved patient-specific instrumentation (PSI) [8e12]. The
# variability of standard templating and cost associated with preoperative computed tomography/magnetic resonance imaging in PSI
# has left surgeons to seek an accurate, time-efficient, and costeffective method of templating in TKA. Whether component sizes
# can be predicted preoperatively by demographic variables alone
# has yet to be addressed in the literature.
# We propose a novel method of templating in TKA based on a
# formula utilizing patient height, weight, and gender. The purpose of

# %% [markdown]
# # Import Libraries

# %%
# Importing all the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import scipy
import statsmodels.api as sm
import missingno as msno
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score




# Supress Warnings
import warnings
warnings.filterwarnings('ignore')

# Set default plotting style
plt.style.use('seaborn-darkgrid')

# %% [markdown]
# # Data Acquisition

# %%
# Training data set
train_df = pd.read_excel('Training Data Set- Clean.xlsx')

# Drop the last column Unnamed: 22
train_df = train_df.iloc[:, :-1]

# Testing data set
test_df = pd.read_excel('Testing Data Set- Clean.xlsx')

# %%
# View the first 5 rows of the training dataset
train_df.head()
# Out:
#   Procedure_TKR2.F_Company Procedure_TKR2.F_Model  \
# 0                   Zimmer                Persona
# 1                   Zimmer      NexGen LPS Option
# 2                   Zimmer   NexGen GS LPS - Flex
# 3                   Zimmer   NexGen GS LPS - Flex
# 4                   Zimmer             Persona CR
#
#                Procedure_TKR2.F_Details  Femur AP Dimension (mm)  \
# 0  Size 6, Left, Cemented, PS, Standard                     60.4
# 1                          Left, Size C                     53.5
# 2                          Left, Size D                     57.5
# 3                         Right, Size F                     65.3
# 4              CR, Narrow, Size 7, Left                     60.8
#
#   Procedure_TKR2.T_Model                      Procedure_TKR2.T_Details  \
# 0                Persona                   Size C, Left, 5 Degree, STM
# 1                 NexGen  Micro/1, 40mm A/P, 58mm M/L, Precoat Stemmed
# 2                 NexGen                       Size 3, PreCoat Stemmed
# 3                 NexGen                       Size 3, PreCoat Stemmed
# 4                Persona                Size D, Left, 5 Degree, NP STM
#
#    Tibia ML Dimension (mm) Procedure_TKR2.Pat_Model  \
# 0                     63.8                  Persona
# 1                     58.0                      NaN
# 2                     66.0  NexGen All-Poly Patella
# 3                     66.0  NexGen All-Poly Patella
# 4                     67.0                  Persona
#
#   Procedure_TKR2.Pat_Details                       Procedure_TKR2.Poly_Model  \
# 0             All poly, 35mm                                         Persona
# 1                        NaN                                             NaN
# 2      32mm, 8.5mm Thickness  NexGen LPS-Flex Fixed Molded Articular Surface
# 3      32mm, 8.5mm Thickness  NexGen LPS-Flex Fixed Molded Articular Surface
# 4             All poly, 32mm                                      Persona CR
#
#    ... Procedure_TKR2.O1_Details Demographics.Gender (0=Female, 1=Male)  \
# 0  ...                       NaN                                    0.0
# 1  ...                       NaN                                    0.0
# 2  ...                       NaN                                    0.0
# 3  ...                       NaN                                    0.0
# 4  ...                       NaN                                    0.0
#
#   Procedure_TKR.Height_cm  Procedure_TKR.Weight_kg  Procedure_TKR.BMI  \
# 0                   60.00                    58.64         162.888889
# 1                  116.84                    62.20          45.562473
# 2                  127.00                    52.00          32.240064
# 3                  124.46                    68.64          44.311625
# 4                  121.92                    75.00          50.455830
#
#    Surgery_Main.Side  Surgery_Main.Procedure Procedure_TKR.Primary_Diagnosis  \
# 0               Left             Primary TKR          Degenerative Arthritis
# 1               Left             Primary TKR                             NaN
# 2               Left             Primary TKR          Degenerative Arthritis
# 3              Right             Primary TKR          Degenerative Arthritis
# 4               Left             Primary TKR          Degenerative Arthritis
#
#   Procedure_TKR.ASARisk Procedure_TKR.Approach
# 0                    II    Medial Parapatellar
# 1                   III    Medial Parapatellar
# 2                   III          MIS-Midvastus
# 3                    II    Medial Parapatellar
# 4                   III          MIS-Midvastus
#
# [5 rows x 22 columns]

# %%
# View the first 5 rows of the testing dataset
test_df.head()
# Out:
#     age right  Demographics.Gender (0=Female, 1=Male)  Procedure_TKR.BMI  \
# 0  59.0     1                                     0.0              30.13
# 1  42.0     0                                     1.0              32.49
# 2  71.0     0                                     0.0              34.00
# 3  83.0     0                                     0.0              24.27
# 4  56.0     1                                     1.0              49.51
#
#    Procedure_TKR.Weight_kg  Procedure_TKR.Height_cm  \
# 0                     95.3                    177.8
# 1                    100.2                    173.2
# 2                     98.4                    170.2
# 3                     62.1                    160.0
# 4                    161.0                    180.3
#
#                  Femoral Model  Femur implanted                Tibial Model  \
# 0             SN Legion Size 6             66.0           Genesis II size 5
# 1             SN Legion Size 7             70.0           Genesis II size 6
# 2  Stryker Triathlon Femoral 5             65.0  Stryker Triathlon Tibial 5
# 3             SN Legion Size 4             59.0           Genesis II size 2
# 4  Stryker Triathlon Femoral 8             75.0  Stryker Triathlon Tibial 7
#
#    Tibia Implanted
# 0             74.0
# 1             77.0
# 2             74.0
# 3             64.0
# 4             80.0

# %%
# Find the name of the columns of the training dataset
print('The column names of the training dataset are:')
print(train_df.columns) 
print()
print()

# Find the name of the columns of the test dataset
print('The column names of the test dataset are:')
print(test_df.columns)
# Out:
# The column names of the training dataset are:
# Index(['Procedure_TKR2.F_Company', 'Procedure_TKR2.F_Model',
#        'Procedure_TKR2.F_Details', 'Femur AP Dimension (mm)',
#        'Procedure_TKR2.T_Model', 'Procedure_TKR2.T_Details',
#        'Tibia ML Dimension (mm)', 'Procedure_TKR2.Pat_Model',
#        'Procedure_TKR2.Pat_Details', 'Procedure_TKR2.Poly_Model',
#        'Procedure_TKR2.Poly_Details', 'Procedure_TKR2.O1_Model',
#        'Procedure_TKR2.O1_Details', 'Demographics.Gender (0=Female, 1=Male)',
#        'Procedure_TKR.Height_cm', 'Procedure_TKR.Weight_kg',
#        'Procedure_TKR.BMI', 'Surgery_Main.Side', 'Surgery_Main.Procedure',
#        'Procedure_TKR.Primary_Diagnosis', 'Procedure_TKR.ASARisk',
#        'Procedure_TKR.Approach'],
#       dtype='object')
#
#
# The column names of the test dataset are:
# Index(['age', 'right', 'Demographics.Gender (0=Female, 1=Male)',
#        'Procedure_TKR.BMI', 'Procedure_TKR.Weight_kg',
#        'Procedure_TKR.Height_cm', 'Femoral Model', 'Femur implanted',
#        'Tibial Model', 'Tibia Implanted'],
#       dtype='object')

# %% [markdown]
# # Basic Insights of The Datasets
# We now explore our datasets to get better understanding of them.

# %% [markdown]
# ## Data Types

# %%
# Get the datatypes of each column of the train dataset
train_df.dtypes
# Out:
# Procedure_TKR2.F_Company                   object
# Procedure_TKR2.F_Model                     object
# Procedure_TKR2.F_Details                   object
# Femur AP Dimension (mm)                   float64
# Procedure_TKR2.T_Model                     object
# Procedure_TKR2.T_Details                   object
# Tibia ML Dimension (mm)                   float64
# Procedure_TKR2.Pat_Model                   object
# Procedure_TKR2.Pat_Details                 object
# Procedure_TKR2.Poly_Model                  object
# Procedure_TKR2.Poly_Details                object
# Procedure_TKR2.O1_Model                    object
# Procedure_TKR2.O1_Details                  object
# Demographics.Gender (0=Female, 1=Male)    float64
# Procedure_TKR.Height_cm                   float64
# Procedure_TKR.Weight_kg                   float64
# Procedure_TKR.BMI                         float64
# Surgery_Main.Side                          object
# Surgery_Main.Procedure                     object
# Procedure_TKR.Primary_Diagnosis            object
# Procedure_TKR.ASARisk                      object
# Procedure_TKR.Approach                     object
# dtype: object

# %%
# Get the datatype of each column of the test dataset
test_df.dtypes
# Out:
# age                                       float64
# right                                      object
# Demographics.Gender (0=Female, 1=Male)    float64
# Procedure_TKR.BMI                         float64
# Procedure_TKR.Weight_kg                   float64
# Procedure_TKR.Height_cm                   float64
# Femoral Model                              object
# Femur implanted                           float64
# Tibial Model                               object
# Tibia Implanted                           float64
# dtype: object

# %% [markdown]
# ## Describe
# Gives a Statistical Summary of each column

# %%
# Get a statistical summary of each column of the train dataset
train_df.describe().transpose()
# Out:
#                                          count        mean        std  \
# Femur AP Dimension (mm)                 3389.0   64.445117  56.865458
# Tibia ML Dimension (mm)                 3384.0   72.255496  57.014339
# Demographics.Gender (0=Female, 1=Male)  3400.0    0.372647   0.483580
# Procedure_TKR.Height_cm                 3393.0  168.853248  56.762893
# Procedure_TKR.Weight_kg                 3399.0   96.577129  61.697155
# Procedure_TKR.BMI                       3385.0   35.346689  29.581954
#
#                                               min         25%         50%  \
# Femur AP Dimension (mm)                 52.300000   59.600000   63.500000
# Tibia ML Dimension (mm)                 43.000000   66.000000   71.000000
# Demographics.Gender (0=Female, 1=Male)   0.000000    0.000000    0.000000
# Procedure_TKR.Height_cm                  0.000000  160.020000  167.640000
# Procedure_TKR.Weight_kg                  0.000000   78.000000   92.300000
# Procedure_TKR.BMI                       12.771436   27.896468   32.227499
#
#                                                75%          max
# Femur AP Dimension (mm)                  66.200000  3363.000000
# Tibia ML Dimension (mm)                  75.100000  3371.000000
# Demographics.Gender (0=Female, 1=Male)    1.000000     1.000000
# Procedure_TKR.Height_cm                 175.260000  3377.000000
# Procedure_TKR.Weight_kg                 109.090000  3377.000000
# Procedure_TKR.BMI                        37.966465   622.558594

# %%
# Get a statistical summary of each column of the test dataset
test_df.describe().transpose()
# Out:
#                                         count        mean        std      min  \
# age                                     495.0   65.060606   9.329786   30.000
# Demographics.Gender (0=Female, 1=Male)  496.0    0.389113   0.488041    0.000
# Procedure_TKR.BMI                       490.0   33.332373   6.857739   18.959
# Procedure_TKR.Weight_kg                 491.0   95.979063  23.122266   44.900
# Procedure_TKR.Height_cm                 491.0  169.359898  11.086556  139.700
# Femur implanted                         491.0   64.157434   5.047097   51.900
# Tibia Implanted                         488.0   71.393033   5.876109   58.000
#
#                                             25%       50%        75%     max
# age                                      59.000   66.0000   71.50000   87.00
# Demographics.Gender (0=Female, 1=Male)    0.000    0.0000    1.00000    1.00
# Procedure_TKR.BMI                        28.638   32.2895   37.45925   62.98
# Procedure_TKR.Weight_kg                  80.300   93.4000  108.70000  195.00
# Procedure_TKR.Height_cm                 160.000  167.7100  177.80000  195.60
# Femur implanted                          59.600   63.0000   67.35000   77.50
# Tibia Implanted                          66.000   71.0000   75.00000   87.00

# %% [markdown]
# Let's get a statistical summary of each column including the object type columns

# %%
# Get a statistical summary of each column of the train dataset
train_df.describe(include = 'all').transpose()
# Out:
#                                          count unique  \
# Procedure_TKR2.F_Company                  3402      6
# Procedure_TKR2.F_Model                    3398     52
# Procedure_TKR2.F_Details                  3396    236
# Femur AP Dimension (mm)                 3389.0    NaN
# Procedure_TKR2.T_Model                    3396     33
# Procedure_TKR2.T_Details                  3392     97
# Tibia ML Dimension (mm)                 3384.0    NaN
# Procedure_TKR2.Pat_Model                  3381     23
# Procedure_TKR2.Pat_Details                3381     60
# Procedure_TKR2.Poly_Model                 3395     65
# Procedure_TKR2.Poly_Details               3396    411
# Procedure_TKR2.O1_Model                    509     33
# Procedure_TKR2.O1_Details                  509     61
# Demographics.Gender (0=Female, 1=Male)  3400.0    NaN
# Procedure_TKR.Height_cm                 3393.0    NaN
# Procedure_TKR.Weight_kg                 3399.0    NaN
# Procedure_TKR.BMI                       3385.0    NaN
# Surgery_Main.Side                         3402      2
# Surgery_Main.Procedure                    3402      1
# Procedure_TKR.Primary_Diagnosis           3385      7
# Procedure_TKR.ASARisk                     3394      4
# Procedure_TKR.Approach                    3378      9
#
#                                                                                       top  \
# Procedure_TKR2.F_Company                                                           Zimmer
# Procedure_TKR2.F_Model                                 NexGen CR-Flex GSF Femoral Precoat
# Procedure_TKR2.F_Details                                              Size E-Minus, Right
# Femur AP Dimension (mm)                                                               NaN
# Procedure_TKR2.T_Model                                                             NexGen
# Procedure_TKR2.T_Details                                          Size 3, PreCoat Stemmed
# Tibia ML Dimension (mm)                                                               NaN
# Procedure_TKR2.Pat_Model                                          NexGen All-Poly Patella
# Procedure_TKR2.Pat_Details                                          32mm, 8.5mm Thickness
# Procedure_TKR2.Poly_Model                                                      Persona CR
# Procedure_TKR2.Poly_Details             Yellow, Size 10/Std, A/P 42mm, M/L 66mm, Femor...
# Procedure_TKR2.O1_Model                                                       NexGen Plug
# Procedure_TKR2.O1_Details                                                      Taper Stem
# Demographics.Gender (0=Female, 1=Male)                                                NaN
# Procedure_TKR.Height_cm                                                               NaN
# Procedure_TKR.Weight_kg                                                               NaN
# Procedure_TKR.BMI                                                                     NaN
# Surgery_Main.Side                                                                   Right
# Surgery_Main.Procedure                                                        Primary TKR
# Procedure_TKR.Primary_Diagnosis                                    Degenerative Arthritis
# Procedure_TKR.ASARisk                                                                  II
# Procedure_TKR.Approach                                                      MIS-Midvastus
#
#                                         freq        mean        std  \
# Procedure_TKR2.F_Company                3160         NaN        NaN
# Procedure_TKR2.F_Model                   808         NaN        NaN
# Procedure_TKR2.F_Details                 133         NaN        NaN
# Femur AP Dimension (mm)                  NaN   64.445117  56.865458
# Procedure_TKR2.T_Model                  1531         NaN        NaN
# Procedure_TKR2.T_Details                 557         NaN        NaN
# Tibia ML Dimension (mm)                  NaN   72.255496  57.014339
# Procedure_TKR2.Pat_Model                1540         NaN        NaN
# Procedure_TKR2.Pat_Details               555         NaN        NaN
# Procedure_TKR2.Poly_Model                669         NaN        NaN
# Procedure_TKR2.Poly_Details              115         NaN        NaN
# Procedure_TKR2.O1_Model                  334         NaN        NaN
# Procedure_TKR2.O1_Details                334         NaN        NaN
# Demographics.Gender (0=Female, 1=Male)   NaN    0.372647    0.48358
# Procedure_TKR.Height_cm                  NaN  168.853248  56.762893
# Procedure_TKR.Weight_kg                  NaN   96.577129  61.697155
# Procedure_TKR.BMI                        NaN   35.346689  29.581954
# Surgery_Main.Side                       1775         NaN        NaN
# Surgery_Main.Procedure                  3402         NaN        NaN
# Procedure_TKR.Primary_Diagnosis         3317         NaN        NaN
# Procedure_TKR.ASARisk                   2237         NaN        NaN
# Procedure_TKR.Approach                  1640         NaN        NaN
#
#                                               min        25%        50%  \
# Procedure_TKR2.F_Company                      NaN        NaN        NaN
# Procedure_TKR2.F_Model                        NaN        NaN        NaN
# Procedure_TKR2.F_Details                      NaN        NaN        NaN
# Femur AP Dimension (mm)                      52.3       59.6       63.5
# Procedure_TKR2.T_Model                        NaN        NaN        NaN
# Procedure_TKR2.T_Details                      NaN        NaN        NaN
# Tibia ML Dimension (mm)                      43.0       66.0       71.0
# Procedure_TKR2.Pat_Model                      NaN        NaN        NaN
# Procedure_TKR2.Pat_Details                    NaN        NaN        NaN
# Procedure_TKR2.Poly_Model                     NaN        NaN        NaN
# Procedure_TKR2.Poly_Details                   NaN        NaN        NaN
# Procedure_TKR2.O1_Model                       NaN        NaN        NaN
# Procedure_TKR2.O1_Details                     NaN        NaN        NaN
# Demographics.Gender (0=Female, 1=Male)        0.0        0.0        0.0
# Procedure_TKR.Height_cm                       0.0     160.02     167.64
# Procedure_TKR.Weight_kg                       0.0       78.0       92.3
# Procedure_TKR.BMI                       12.771436  27.896468  32.227499
# Surgery_Main.Side                             NaN        NaN        NaN
# Surgery_Main.Procedure                        NaN        NaN        NaN
# Procedure_TKR.Primary_Diagnosis               NaN        NaN        NaN
# Procedure_TKR.ASARisk                         NaN        NaN        NaN
# Procedure_TKR.Approach                        NaN        NaN        NaN
#
#                                               75%         max
# Procedure_TKR2.F_Company                      NaN         NaN
# Procedure_TKR2.F_Model                        NaN         NaN
# Procedure_TKR2.F_Details                      NaN         NaN
# Femur AP Dimension (mm)                      66.2      3363.0
# Procedure_TKR2.T_Model                        NaN         NaN
# Procedure_TKR2.T_Details                      NaN         NaN
# Tibia ML Dimension (mm)                      75.1      3371.0
# Procedure_TKR2.Pat_Model                      NaN         NaN
# Procedure_TKR2.Pat_Details                    NaN         NaN
# Procedure_TKR2.Poly_Model                     NaN         NaN
# Procedure_TKR2.Poly_Details                   NaN         NaN
# Procedure_TKR2.O1_Model                       NaN         NaN
# Procedure_TKR2.O1_Details                     NaN         NaN
# Demographics.Gender (0=Female, 1=Male)        1.0         1.0
# Procedure_TKR.Height_cm                    175.26      3377.0
# Procedure_TKR.Weight_kg                    109.09      3377.0
# Procedure_TKR.BMI                       37.966465  622.558594
# Surgery_Main.Side                             NaN         NaN
# Surgery_Main.Procedure                        NaN         NaN
# Procedure_TKR.Primary_Diagnosis               NaN         NaN
# Procedure_TKR.ASARisk                         NaN         NaN
# Procedure_TKR.Approach                        NaN         NaN

# %%
# Get a statistical summary of each column of the train dataset
test_df.describe(include = 'all').transpose()
# Out:
#                                         count unique                top  \
# age                                     495.0    NaN                NaN
# right                                   496.0    3.0                1.0
# Demographics.Gender (0=Female, 1=Male)  496.0    NaN                NaN
# Procedure_TKR.BMI                       490.0    NaN                NaN
# Procedure_TKR.Weight_kg                 491.0    NaN                NaN
# Procedure_TKR.Height_cm                 491.0    NaN                NaN
# Femoral Model                             491    160   SN Legion size 6
# Femur implanted                         491.0    NaN                NaN
# Tibial Model                              491    151  Genesis II size 4
# Tibia Implanted                         488.0    NaN                NaN
#
#                                          freq        mean        std     min  \
# age                                       NaN   65.060606   9.329786    30.0
# right                                   261.0         NaN        NaN     NaN
# Demographics.Gender (0=Female, 1=Male)    NaN    0.389113   0.488041     0.0
# Procedure_TKR.BMI                         NaN   33.332373   6.857739  18.959
# Procedure_TKR.Weight_kg                   NaN   95.979063  23.122266    44.9
# Procedure_TKR.Height_cm                   NaN  169.359898  11.086556   139.7
# Femoral Model                              31         NaN        NaN     NaN
# Femur implanted                           NaN   64.157434   5.047097    51.9
# Tibial Model                               41         NaN        NaN     NaN
# Tibia Implanted                           NaN   71.393033   5.876109    58.0
#
#                                            25%      50%       75%    max
# age                                       59.0     66.0      71.5   87.0
# right                                      NaN      NaN       NaN    NaN
# Demographics.Gender (0=Female, 1=Male)     0.0      0.0       1.0    1.0
# Procedure_TKR.BMI                       28.638  32.2895  37.45925  62.98
# Procedure_TKR.Weight_kg                   80.3     93.4     108.7  195.0
# Procedure_TKR.Height_cm                  160.0   167.71     177.8  195.6
# Femoral Model                              NaN      NaN       NaN    NaN
# Femur implanted                           59.6     63.0     67.35   77.5
# Tibial Model                               NaN      NaN       NaN    NaN
# Tibia Implanted                           66.0     71.0      75.0   87.0

# %% [markdown]
# ## Info

# %% [markdown]
# It provides a concise summary of your DataFrame.
#
# This method prints information about a DataFrame including the index dtype and columns, non-null values and memory usage.

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3407 entries, 0 to 3406
# Data columns (total 22 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Procedure_TKR2.F_Company                3402 non-null   object
#  1   Procedure_TKR2.F_Model                  3398 non-null   object
#  2   Procedure_TKR2.F_Details                3396 non-null   object
#  3   Femur AP Dimension (mm)                 3389 non-null   float64
#  4   Procedure_TKR2.T_Model                  3396 non-null   object
#  5   Procedure_TKR2.T_Details                3392 non-null   object
#  6   Tibia ML Dimension (mm)                 3384 non-null   float64
#  7   Procedure_TKR2.Pat_Model                3381 non-null   object
#  8   Procedure_TKR2.Pat_Details              3381 non-null   object
#  9   Procedure_TKR2.Poly_Model               3395 non-null   object
#  10  Procedure_TKR2.Poly_Details             3396 non-null   object
#  11  Procedure_TKR2.O1_Model                 509 non-null    object
#  12  Procedure_TKR2.O1_Details               509 non-null    object
#  13  Demographics.Gender (0=Female, 1=Male)  3400 non-null   float64
#  14  Procedure_TKR.Height_cm                 3393 non-null   float64
#  15  Procedure_TKR.Weight_kg                 3399 non-null   float64
#  16  Procedure_TKR.BMI                       3385 non-null   float64
#  17  Surgery_Main.Side                       3402 non-null   object
#  18  Surgery_Main.Procedure                  3402 non-null   object
#  19  Procedure_TKR.Primary_Diagnosis         3385 non-null   object
#  20  Procedure_TKR.ASARisk                   3394 non-null   object
#  21  Procedure_TKR.Approach                  3378 non-null   object
# dtypes: float64(6), object(16)
# memory usage: 585.7+ KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 513 entries, 0 to 512
# Data columns (total 10 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   age                                     495 non-null    float64
#  1   right                                   496 non-null    object
#  2   Demographics.Gender (0=Female, 1=Male)  496 non-null    float64
#  3   Procedure_TKR.BMI                       490 non-null    float64
#  4   Procedure_TKR.Weight_kg                 491 non-null    float64
#  5   Procedure_TKR.Height_cm                 491 non-null    float64
#  6   Femoral Model                           491 non-null    object
#  7   Femur implanted                         491 non-null    float64
#  8   Tibial Model                            491 non-null    object
#  9   Tibia Implanted                         488 non-null    float64
# dtypes: float64(7), object(3)
# memory usage: 40.2+ KB

# %% [markdown]
# # Feature Selection

# %% [markdown]
# Before we move to Data Wrangling and Exploratory Data Analysis, we trim our dataset to the desired variables needed for the purpose of our study.
# The variables needed as predictors are age, height, weight, BMI, gender and the side where the surgery was done (left or right). Whereas the response variables are Femur and tibia dimensions.

# %%
train_df = train_df[['Femur AP Dimension (mm)', 'Tibia ML Dimension (mm)', 'Demographics.Gender (0=Female, 1=Male)', 'Procedure_TKR.Height_cm','Procedure_TKR.Weight_kg', 'Procedure_TKR.BMI', 'Surgery_Main.Side']]
train_df
# Out:
#       Femur AP Dimension (mm)  Tibia ML Dimension (mm)  \
# 0                        60.4                     63.8
# 1                        53.5                     58.0
# 2                        57.5                     66.0
# 3                        65.3                     66.0
# 4                        60.8                     67.0
# ...                       ...                      ...
# 3402                     70.4                     74.0
# 3403                     70.5                     82.0
# 3404                     61.5                     66.0
# 3405                     62.0                     70.0
# 3406                     71.0                     80.0
#
#       Demographics.Gender (0=Female, 1=Male)  Procedure_TKR.Height_cm  \
# 0                                        0.0                    60.00
# 1                                        0.0                   116.84
# 2                                        0.0                   127.00
# 3                                        0.0                   124.46
# 4                                        0.0                   121.92
# ...                                      ...                      ...
# 3402                                     NaN                      NaN
# 3403                                     1.0                      NaN
# 3404                                     0.0                     0.00
# 3405                                     0.0                     0.00
# 3406                                     1.0                     0.00
#
#       Procedure_TKR.Weight_kg  Procedure_TKR.BMI Surgery_Main.Side
# 0                       58.64         162.888889              Left
# 1                       62.20          45.562473              Left
# 2                       52.00          32.240064              Left
# 3                       68.64          44.311625             Right
# 4                       75.00          50.455830              Left
# ...                       ...                ...               ...
# 3402                      NaN                NaN             Right
# 3403                   102.27                NaN              Left
# 3404                    94.00                NaN              Left
# 3405                     0.00                NaN             Right
# 3406                     0.00                NaN              Left
#
# [3407 rows x 7 columns]

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# Data wrangling is the process of converting data from the initial format to a format that may be better for analysis.

# %% [markdown]
# Based on some preliminary analysis, there are rows with extremely high values and very low values which seem so unreal
#
# <b> Check and drop the outlier</b>

# %%
train_df.sort_values("Procedure_TKR.BMI", ascending = False).head(20)
# Out:
#       Femur AP Dimension (mm)  Tibia ML Dimension (mm)  \
# 2676                     61.2                     74.0
# 2602                     55.7                     66.0
# 3028                     61.5                     74.0
# 3325                     65.5                     82.0
# 3240                     70.0                     75.0
# 2400                     61.5                     66.0
# 2397                     61.5                     66.0
# 2971                     61.5                     74.0
# 3112                     65.5                     74.0
# 2391                     59.4                     66.0
# 2386                     57.5                     66.0
# 2411                     59.4                     66.0
# 2387                     57.5                     66.0
# 2383                     61.5                     66.0
# 0                        60.4                     63.8
# 2398                     55.7                     66.0
# 1351                     59.4                     66.0
# 2995                     65.5                     74.0
# 32                       59.4                     66.0
# 2790                     57.5                     62.0
#
#       Demographics.Gender (0=Female, 1=Male)  Procedure_TKR.Height_cm  \
# 2676                                     0.0                    64.00
# 2602                                     0.0                    63.00
# 3028                                     0.0                    66.00
# 3325                                     1.0                    72.00
# 3240                                     1.0                    72.50
# 2400                                     0.0                    64.00
# 2397                                     0.0                    65.00
# 2971                                     0.0                    70.00
# 3112                                     1.0                    72.00
# 2391                                     0.0                    65.00
# 2386                                     0.0                    60.50
# 2411                                     0.0                    69.00
# 2387                                     0.0                    64.00
# 2383                                     0.0                    63.00
# 0                                        0.0                    60.00
# 2398                                     0.0                   121.92
# 1351                                     0.0                   152.40
# 2995                                     0.0                   137.16
# 32                                       0.0                   121.92
# 2790                                     0.0                   149.86
#
#       Procedure_TKR.Weight_kg  Procedure_TKR.BMI Surgery_Main.Side
# 2676                   255.00         622.558594             Right
# 2602                   242.00         609.725372             Right
# 3028                   255.00         585.399449              Left
# 3325                   260.00         501.543210              Left
# 3240                   260.00         494.649227              Left
# 2400                   193.00         471.191406             Right
# 2397                   190.00         449.704142              Left
# 2971                   218.40         445.714286              Left
# 3112                   231.00         445.601852              Left
# 2391                   180.00         426.035503              Left
# 2386                   148.00         404.343966             Right
# 2411                   190.00         399.075824             Right
# 2387                   145.00         354.003906              Left
# 2383                   135.00         340.136054              Left
# 0                       58.64         162.888889              Left
# 2398                   102.27          68.801570             Right
# 1351                   159.30          68.587637             Right
# 2995                   128.64          68.378738             Right
# 32                      99.50          66.938068             Right
# 2790                   150.00          66.791286             Right

# %%
train_df = train_df.drop(train_df[(train_df['Procedure_TKR.Weight_kg'] == 0.0) | (train_df['Procedure_TKR.Height_cm'] == 0.0)
                                 | (train_df['Femur AP Dimension (mm)'] == 3363.0)].index)

# %%
train_df.describe()
# Out:
#        Femur AP Dimension (mm)  Tibia ML Dimension (mm)  \
# count              3385.000000              3380.000000
# mean                 63.470310                71.279763
# std                   4.611702                 5.753656
# min                  52.300000                43.000000
# 25%                  59.600000                66.000000
# 50%                  63.500000                71.000000
# 75%                  66.200000                75.100000
# max                  81.000000                89.000000
#
#        Demographics.Gender (0=Female, 1=Male)  Procedure_TKR.Height_cm  \
# count                             3397.000000              3389.000000
# mean                                 0.372682               168.056084
# std                                  0.483590                12.732126
# min                                  0.000000                60.000000
# 25%                                  0.000000               160.020000
# 50%                                  0.000000               167.640000
# 75%                                  1.000000               175.260000
# max                                  1.000000               208.280000
#
#        Procedure_TKR.Weight_kg  Procedure_TKR.BMI
# count              3395.000000        3385.000000
# mean                 95.668530          35.346689
# std                  25.180441          29.581954
# min                  36.290000          12.771436
# 25%                  78.000000          27.896468
# 50%                  92.300000          32.227499
# 75%                 109.090000          37.966465
# max                 260.000000         622.558594

# %% [markdown]
# We first check for duplicates in our data and drop them
#
# <b> Check and drop duplicates</b>

# %%
# Checking and dropping duplicates in the test dataset
print(test_df.duplicated().sum())
test_df.drop_duplicates(inplace = True)

# Checking and dropping duplicates in the train dataset
print(train_df.duplicated().sum())
train_df.drop_duplicates(inplace = True)
# Out:
# 17
# 40

# %% [markdown]
# As we can see, several NaN appeared in the dataframe; those are missing values which may hinder our further analysis.
#
# <div>So, how do we identify all those missing values and deal with them?</div>
#
# <b>How to work with missing data?</b>
#
# Steps for working with missing data:
#
# <ol>
#     <li>Identify missing data</li>
#     <li>Deal with missing data</li>
#     <li>Correct data format</li>
# </ol>

# %% [markdown]
# <h4>Evaluating for Missing Data</h4>
#
# The missing values are converted by default. We use the following functions to identify these missing values. There are two methods to detect missing data:
#
# <ol>
#     <li><b>.isnull()</b></li>
#     <li><b>.notnull()</b></li>
# </ol>
# The output is a boolean value indicating whether the value that is passed into the argument is in fact missing data.

# %%
missing_data = train_df.isnull()
missing_data.head(5)
# Out:
#    Femur AP Dimension (mm)  Tibia ML Dimension (mm)  \
# 0                    False                    False
# 1                    False                    False
# 2                    False                    False
# 3                    False                    False
# 4                    False                    False
#
#    Demographics.Gender (0=Female, 1=Male)  Procedure_TKR.Height_cm  \
# 0                                   False                    False
# 1                                   False                    False
# 2                                   False                    False
# 3                                   False                    False
# 4                                   False                    False
#
#    Procedure_TKR.Weight_kg  Procedure_TKR.BMI  Surgery_Main.Side
# 0                    False              False              False
# 1                    False              False              False
# 2                    False              False              False
# 3                    False              False              False
# 4                    False              False              False

# %% [markdown]
# "True" means the value is a missing value while "False" means the value is not a missing value.

# %% [markdown]
# <h4>Count missing values in each column</h4>
# <p>
# Using a for loop in Python, we can quickly figure out the number of missing values in each column. As mentioned above, "True" represents a missing value and "False" means the value is present in the dataset.  In the body of the for loop the method ".value_counts()" counts the number of "True" values.
# </p>

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# Femur AP Dimension (mm)
# False    3348
# True       15
# Name: Femur AP Dimension (mm), dtype: int64
#
# Tibia ML Dimension (mm)
# False    3343
# True       20
# Name: Tibia ML Dimension (mm), dtype: int64
#
# Demographics.Gender (0=Female, 1=Male)
# False    3360
# True        3
# Name: Demographics.Gender (0=Female, 1=Male), dtype: int64
#
# Procedure_TKR.Height_cm
# False    3352
# True       11
# Name: Procedure_TKR.Height_cm, dtype: int64
#
# Procedure_TKR.Weight_kg
# False    3358
# True        5
# Name: Procedure_TKR.Weight_kg, dtype: int64
#
# Procedure_TKR.BMI
# False    3348
# True       15
# Name: Procedure_TKR.BMI, dtype: int64
#
# Surgery_Main.Side
# False    3362
# True        1
# Name: Surgery_Main.Side, dtype: int64

# %%
# Gives a bar chart of the missing values
msno.bar(train_df);

# %%
# Gives positional information of the missing values
msno.matrix(train_df);

# %%
# Gives a heatmap of how missing values are related
msno.heatmap(train_df, cmap = 'YlGnBu');

# %%
# Missing data dendrogram
msno.dendrogram(train_df);

# %% [markdown]
# Whole columns should be dropped only if most entries in the column are empty. In our dataset, none of the columns are empty enough to drop entirely.
# We have some freedom in choosing which method to replace data; however, some methods may seem more reasonable than others. We will apply each method to many different columns:
#
# <b>Replace by mean:</b>
#
# <ul>
#     <li>"Procedure_TKR.BMI": 22 missing data, replace them with mean</li>
#     <li>"Procedure_TKR.Height_cm": 14 missing data, replace them with mean</li>
#     <li>"Procedure_TKR.Weight_kg": 8 missing data, replace them with mean</li>
#
# </ul>
#
# <b>Replace by frequency:</b>
#
# <ul>
#     <li>"Demographics.Gender (0=Female, 1=Male)": 7 missing data, replace them with 0.0. </li>
#         <ul>
#             <li>Reason: Since 0.0 doors is most frequent, it is most likely to occur.</li>
#         </ul>
#     <li>"Surgery_Main.Side": 5 missing data, replace them with "Right"
#         <ul>
#             <li>Reason: Since "Right" is most frequent, it is most likely to occur.</li>
#         </ul>
# </ul>
#
# <b>Drop the whole row:</b>
#
# <ul>
#         <li>"Femur AP Dimension (mm)": 18 missing data, simply delete the whole row
#         <li>"Tibia ML Dimension (mm)": 23 missing data, simply delete the whole row
#         <ul>
#             <li>Reason: Femur and Tibia Dimensions are what we want to predict. Any data entry without Tibia and Femur data cannot be used for prediction; therefore any row now without Tibia and Femur data is not useful to us </li>
#         </ul>
#     </li>
# </ul>

# %% [markdown]
# <h4>Replace "NaN" with mean value in "Procedure_TKR.BMI" column</h4>

# %%
avg_Procedure_TKRBMI = train_df["Procedure_TKR.BMI"].astype("float").mean(axis=0)
print("Average of Procedure_TKR.BMI:", avg_Procedure_TKRBMI)
train_df["Procedure_TKR.BMI"].replace(np.nan, avg_Procedure_TKRBMI, inplace=True)
# Out:
# Average of Procedure_TKR.BMI: 35.37575882082826

# %% [markdown]
# <h4>Replace "NaN" with mean value in "Procedure_TKR.Height_cm" column</h4>

# %%
avg_Procedure_TKRHeight = train_df["Procedure_TKR.Height_cm"].astype("float").mean(axis=0)
print("Average of Procedure_TKR.Height_cm:", avg_Procedure_TKRHeight)
train_df["Procedure_TKR.Height_cm"].replace(np.nan, avg_Procedure_TKRHeight, inplace=True)
# Out:
# Average of Procedure_TKR.Height_cm: 168.05309964200532

# %% [markdown]
# <h4>Replace "NaN" with mean value in "Procedure_TKR.Weight_kg" column</h4>

# %%
avg_Procedure_TKRWeight = train_df["Procedure_TKR.Weight_kg"].astype("float").mean(axis=0)
print("Average of Procedure_TKR.Weight_kg:", avg_Procedure_TKRWeight)
train_df["Procedure_TKR.Weight_kg"].replace(np.nan, avg_Procedure_TKRWeight, inplace=True)
# Out:
# Average of Procedure_TKR.Weight_kg: 95.70190291840407

# %% [markdown]
# #### replace the missing 'Demographics.Gender (0=Female, 1=Male)' values by the most frequent

# %%
# We use ".idxmax()" method to calculate the most common class automatically:
train_df["Demographics.Gender (0=Female, 1=Male)"].value_counts().idxmax()

#replace the missing 'Demographics.Gender (0=Female, 1=Male)' values by the most frequent 
train_df["Demographics.Gender (0=Female, 1=Male)"].replace(np.nan, 0.0, inplace=True)

# %% [markdown]
# #### replace the missing 'Surgery_Main.Side' values by the most frequent

# %%
# We use ".idxmax()" method to calculate the most common class automatically:
train_df["Surgery_Main.Side"].value_counts().idxmax()

#replace the missing 'Surgery_Main.Side' values by the most frequent 
train_df["Surgery_Main.Side"].replace(np.nan, "Right", inplace=True)

# %%
# simply drop whole row with NaN in "Tibia ML Dimension (mm)" column
train_df.dropna(subset=["Tibia ML Dimension (mm)"], axis=0, inplace=True)

# simply drop whole row with NaN in "Femur AP Dimension (mm)" column
train_df.dropna(subset=["Femur AP Dimension (mm)"], axis=0, inplace=True)

# reset index, because we droped some rows
train_df.reset_index(drop=True, inplace=True)

# %%
train_df.head()
# Out:
#    Femur AP Dimension (mm)  Tibia ML Dimension (mm)  \
# 0                     60.4                     63.8
# 1                     53.5                     58.0
# 2                     57.5                     66.0
# 3                     65.3                     66.0
# 4                     60.8                     67.0
#
#    Demographics.Gender (0=Female, 1=Male)  Procedure_TKR.Height_cm  \
# 0                                     0.0                    60.00
# 1                                     0.0                   116.84
# 2                                     0.0                   127.00
# 3                                     0.0                   124.46
# 4                                     0.0                   121.92
#
#    Procedure_TKR.Weight_kg  Procedure_TKR.BMI Surgery_Main.Side
# 0                    58.64         162.888889              Left
# 1                    62.20          45.562473              Left
# 2                    52.00          32.240064              Left
# 3                    68.64          44.311625             Right
# 4                    75.00          50.455830              Left

# %% [markdown]
# #### Counting missing values in each column

# %%
train_df.isnull().sum()
# Out:
# Femur AP Dimension (mm)                   0
# Tibia ML Dimension (mm)                   0
# Demographics.Gender (0=Female, 1=Male)    0
# Procedure_TKR.Height_cm                   0
# Procedure_TKR.Weight_kg                   0
# Procedure_TKR.BMI                         0
# Surgery_Main.Side                         0
# dtype: int64

# %% [markdown]
# We now clean the test dataset

# %%
# Feature Selection to match the train set features
test_df = test_df[["right", "Demographics.Gender (0=Female, 1=Male)", 
                   "Procedure_TKR.BMI", "Procedure_TKR.Weight_kg", 
                   "Procedure_TKR.Height_cm", "Femur implanted", "Tibia Implanted"]]
with pd.option_context("display.max_rows", None,
                      "display.max_columns", None,
                      "display.precision", 3):
    print(test_df)
# Out:
#        right  Demographics.Gender (0=Female, 1=Male)  Procedure_TKR
# 493        1                                     0.0             46.505
# 494        0                                     1.0                NaN
# 495        1                                     1.0                NaN
# 496        0                                     0.0             23.743
# 497        1                                     0.0             44.111
# 498      NaN                                     NaN                NaN
# 499        0                                     0.0                NaN
# 500        0                                     0.0             32.907
# 501        0                                     0.0                NaN
# 502        1                                     1.0                NaN
# 503        0                                     0.0             25.030
# 504        0                                     0.0             32.377
# 505        1                                     0.0             33.459
# 506        1                                     1.0             29.560
# 507        0                                     0.0             36.205
# 508        1                                     0.0             29.876
# 509        1                                     0.0             28.499
# 510        0                                     0.0             20.842
# 511        1                                     0.0             36.400
# 512        1                                     0.0             29.066
#
#      Procedure_TKR.Weight_kg  Procedure_TKR.Height_cm  Femur implanted  \
# 0                      95.30                   177.80             66.0
# 1                     100.20                   173.20             70.0
# 2                      98.40                   170.20             65.0
# 3                      62.10                   160.00             59.0
# 4                     161.00                   180.30             75.0
# 5                      75.80                   148.60             59.0
# 6                      86.20                   170.20             66.0
# 7                     176.90                   167.60             58.2
# 8                     110.20                   161.90             60.2
# 9                      74.90                   160.00             64.2
# 10                     91.60                   154.90             63.0
# 11                    107.00                   170.20             63.0
# 12                     92.50                   175.30             66.0
# 13                     77.70                   172.70             66.0
# 14                    113.90                   182.90             70.0
# 15                    133.40                   177.80             75.0
# 16                    130.00                   171.50             63.0
# 17                    135.20                   188.00             63.0
# 18                    134.30                   180.30             65.0
# 19                    112.00                   188.00             70.0
# 20                     92.50                   172.70             63.0
# 21                     99.80                   157.50             59.0
# 22                    107.50                   160.00             66.0
# 23                    124.70                   177.80             66.0
# 24                     66.20                   157.50             59.0
# 25                     83.00                   162.60             56.4
# 26                     84.00                   170.20             63.0
# 27                     79.40                   159.40             57.5
# 28                     81.20                   152.00             56.0
# 29                     90.20                   160.00             55.0
# 30                     97.50                   157.50             63.0
# 31                    106.10                   167.60             59.0
# 32                     79.40                   152.40             59.0
# 33                    140.20                   175.30             68.0
# 34                     98.40                   157.50             55.0
# 35                     90.70                   160.00             66.0
# 36                    107.90                   165.10             63.0
# 37                       NaN                      NaN              NaN
# 38                    106.60                   152.40             62.0
# 39                     92.50                   160.00             63.0
# 40                     82.70                   158.50             55.0
# 41                     71.70                   165.10             65.0
# 42                     99.20                   180.30             66.0
# 43                    127.00                   177.80             66.0
# 44                    129.30                   175.30             66.0
# 45                     84.80                   188.00             70.0
# 46                    134.70                   190.50             66.0
# 47                    111.60                   188.00             70.0
# 48                    103.00                   160.00             63.0
# 49                     89.80                   150.50             59.0
# 50                     80.30                   162.00             63.0
# 51                     87.10                   165.10             63.0
# 52                     84.40                   157.50             63.0
# 53                    149.70                   193.00             75.0
# 54                     97.10                   180.30             68.0
# 55                     95.30                   160.00             63.0
# 56                    115.80                   162.60             62.0
# 57                    111.10                   177.80             64.2
# 58                    143.80                   182.90             75.0
# 59                    127.00                   171.50             58.2
# 60                    106.10                   165.00             66.0
# 61                     90.30                   161.30             59.0
# 62                    117.90                   180.30             66.0
# 63                     72.60                   167.60             66.0
# 64                     88.00                   165.10             63.0
# 65                    149.40                   188.00             66.0
# 66                    111.10                   162.60             67.0
# 67                     72.10                   147.30             59.0
# 68                     86.20                   160.00             66.0
# 69                     84.40                   168.90             59.0
# 70                     98.90                   157.50             63.0
# 71                    108.90                   180.30             70.0
# 72                     90.70                   170.20             66.0
# 73                     93.90                   170.20             65.0
# 74                     64.50                   170.20             65.0
# 75                     84.80                   147.30             62.5
# 76                     87.50                   177.80             71.1
# 77                     88.50                   170.20             62.1
# 78                     88.90                   167.60             62.1
# 79                     48.50                   160.00             62.1
# 80                     59.00                   166.40             64.6
# 81                     93.40                   180.30             66.2
# 82                     80.30                   175.30             63.8
# 83                     88.00                   166.40             62.1
# 84                     86.60                   156.20             59.0
# 85                    106.60                   185.40             68.5
# 86                     89.80                   170.20             63.8
# 87                     82.60                   175.30             70.0
# 88                    114.30                   180.30             67.5
# 89                    118.30                   162.60             57.2
# 90                     70.00                   152.40             59.0
# 91                    108.50                   175.30             70.0
# 92                     78.90                   160.00             59.0
# 93                     65.00                   157.50             66.0
# 94                     80.70                   182.90             70.0
# 95                     84.70                   165.10             59.0
# 96                    134.20                   190.50             63.0
# 97                    107.50                   182.90             75.0
# 98                    152.70                   182.90             70.0
# 99                     92.00                   177.80             72.5
# 100                   109.80                   163.80             62.5
# 101                    97.50                   170.20             72.5
# 102                    77.10                   170.20             63.0
# 103                    74.40                   162.60             59.0
# 104                   115.20                   165.10             66.0
# 105                    66.20                   172.70             59.6
# 106                   140.50                   189.20             67.2
# 107                   102.10                   172.70             59.6
# 108                   102.10                   165.10             55.6
# 109                    73.90                   175.30             71.1
# 110                   116.10                   177.80             70.5
# 112                   100.70                   167.60             59.6
# 113                   104.40                   180.30             63.8
# 114                    88.90                   167.60             59.6
# 115                    83.90                   170.20             63.0
# 116                    65.30                   160.00             59.6
# 117                   144.20                   160.00             59.6
# 118                   107.60                   172.70             62.1
# 119                   106.60                   149.90             53.2
# 120                    76.20                   165.10             57.2
# 121                   122.00                   179.10             70.0
# 123                    68.00                   177.80             63.0
# 124                   104.40                   190.50             66.0
# 125                    95.90                   182.90             70.0
# 126                    79.40                   165.10             63.0
# 127                    70.80                   152.40             55.0
# 128                   136.10                   185.40             70.0
# 129                   117.90                   177.80             66.0
# 130                    92.50                   162.60             59.0
# 131                   109.80                   171.50             63.0
# 132                    78.50                   165.10             63.0
# 133                    81.60                   170.20             59.0
# 134                   113.40                   170.20             67.5
# 135                    88.50                   165.10             62.1
# 136                   112.00                   180.30             62.1
# 137                    87.10                   165.10             59.6
# 138                    88.50                   172.70             62.1
# 139                    98.00                   179.10             63.8
# 140                    69.40                   154.90             55.6
# 141                    82.10                   162.60             62.5
# 142                   102.50                   168.90             59.0
# 143                    99.80                   186.70             70.0
# 144                    93.00                   177.80             66.0
# ...
# 449                    92.50                   177.80             71.1
# 450                   119.30                   165.10             68.5
# 451                    93.90                   179.10             62.1
# 452                    73.90                   167.60             63.8
# 453                    62.20                   152.40             62.5
# 454                   119.30                   162.60             65.0
# 455                    68.90                   149.90             57.5
# 456                   101.20                   185.40             70.0
# 457                    96.20                   172.70             62.5
# 458                    86.20                   144.80             60.0
# 459                    61.90                   154.90             59.6
# 460                    96.30                   182.90             59.6
# 461                    88.90                   167.60             63.8
# 462                   141.10                   193.00             72.5
# 463                   108.00                   177.80             68.5
# 464                    98.00                   177.80             62.1
# 465                    44.90                   152.40             53.2
# 466                    93.40                   172.70             63.8
# 467                    60.80                   167.60             59.6
# 468                   108.90                   185.40             66.2
# 469                    94.30                   147.30             57.2
# 470                   108.90                   177.80             66.2
# 471                    69.90                   170.20             59.0
# 472                    90.30                   175.30             66.0
# 473                    78.00                   162.60             63.0
# 474                   105.70                   180.30             66.0
# 475                    80.70                   163.80             59.0
# 476                   122.00                   165.10             66.0
# 477                    88.90                   170.20             63.0
# 478                    85.70                   175.30             70.0
# 479                    83.50                   160.00             63.0
# 480                    93.00                   180.30             66.0
# 481                   120.20                   174.00             59.0
# 482                   105.20                   147.30             54.0
# 483                    79.80                   154.90             59.0
# 484                    97.50                   162.60             61.5
# 485                   108.90                   175.30             70.0
# 486                    93.90                   154.90             55.0
# 487                   117.90                   172.70             64.0
# 489                   114.30                   161.90             61.5
# 491                    70.80                   160.00             56.0
# 493                   111.60                   154.90             59.0
# 494                      NaN                      NaN              NaN
# 495                      NaN                      NaN              NaN
# 496                    60.80                   160.00             63.0
# 497                    95.70                   147.30             55.0
# 498                      NaN                      NaN              NaN
# 499                      NaN                      NaN              NaN
# 500                    80.30                   156.20             59.0
# 501                      NaN                      NaN              NaN
# 502                      NaN                      NaN              NaN
# 503                    70.30                   167.60             59.0
# 504                    81.60                   158.80             63.0
# 505                    99.80                   172.70             59.0
# 506                    98.90                   182.90             70.0
# 507                    89.80                   157.50             59.0
# 508                    67.10                   149.90             59.0
# 509                    82.60                   170.20             63.0
# 510                    73.70                   188.00             70.0
# 511                    99.92                   167.71             63.0
# 512                    81.60                   167.60             63.0
#
#      Tibia Implanted
# 0               74.0
# 1               77.0
# 2               74.0
# 3               64.0
# 4               80.0
# 5               64.0
# 6               71.0
# 7               66.0
# 8               66.0
# 9               66.0
# 10              68.0
# 11              68.0
# 12              74.0
# 13              77.0
# 14              77.0
# 15              81.0
# 16              74.0
# 17              74.0
# 18              70.0
# 19              81.0
# 20              71.0
# 21              64.0
# 22              71.0
# 23              71.0
# 24              67.0
# 25              66.0
# 26              71.0
# 27              66.0
# 28              64.0
# 29              64.0
# 30              71.0
# 31              64.0
# 32              64.0
# 33              77.0
# 34              64.0
# 35              71.0
# 36              71.0
# 37               NaN
# 38              70.0
# 39              68.0
# 40              64.0
# 41              70.0
# 42              77.0
# 43              77.0
# 44              74.0
# 45              81.0
# 46              77.0
# 47              77.0
# 48              71.0
# 49              64.0
# 50              71.0
# 51              71.0
# 52              68.0
# 53              81.0
# 54              74.0
# 55              68.0
# 56              70.0
# 57              74.0
# 58              80.0
# 59              66.0
# 60              68.0
# 61              68.0
# 62              77.0
# 63              74.0
# 64              68.0
# 65              77.0
# 66              79.0
# 67              64.0
# 68              71.0
# 69              71.0
# 70              68.0
# 471             68.0
# 472             74.0
# 473             68.0
# 474             77.0
# 475             68.0
# 476             71.0
# 477             71.0
# 478             74.0
# 479             71.0
# 480             77.0
# 481             71.0
# 482              NaN
# 483             68.0
# 484             66.0
# 485             85.0
# 486             60.0
# 487              NaN
# 489             66.0
# 491             67.0
# 493             70.0
# 494              NaN
# 495              NaN
# 496             71.0
# 497             60.0
# 498              NaN
# 499              NaN
# 500             64.0
# 501              NaN
# 502              NaN
# 503             68.0
# 504             68.0
# 505             71.0
# 506             81.0
# 507             64.0
# 508             68.0
# 509             71.0
# 510             74.0
# 511             71.0
# 512             71.0

# %%
missing_test_data = test_df.isnull()
missing_test_data.head(5)
# Out:
#    right  Demographics.Gender (0=Female, 1=Male)  Procedure_TKR.BMI  \
# 0  False                                   False              False
# 1  False                                   False              False
# 2  False                                   False              False
# 3  False                                   False              False
# 4  False                                   False              False
#
#    Procedure_TKR.Weight_kg  Procedure_TKR.Height_cm  Femur implanted  \
# 0                    False                    False            False
# 1                    False                    False            False
# 2                    False                    False            False
# 3                    False                    False            False
# 4                    False                    False            False
#
#    Tibia Implanted
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False

# %% [markdown]
# "True" means the value is a missing value while "False" means the value is not a missing value.

# %% [markdown]
# <h4>Count missing values in each column</h4>

# %%
test_df.isnull().sum()
# Out:
# right                                      2
# Demographics.Gender (0=Female, 1=Male)     2
# Procedure_TKR.BMI                          8
# Procedure_TKR.Weight_kg                    7
# Procedure_TKR.Height_cm                    7
# Femur implanted                            7
# Tibia Implanted                           10
# dtype: int64

# %%
# Gives a bar chart of the missing values
msno.bar(test_df);

# %%
# Gives positional information of the missing values
msno.matrix(test_df);

# %%
# Gives a heatmap of how missing values are related
msno.heatmap(test_df, cmap = 'YlGnBu');

# %%
# Missing data dendrogram
msno.dendrogram(test_df);

# %% [markdown]
# There is a high correlation of nullity in the variables in our test dataset therefore we can initially drop entire rows where values are missing in each column.

# %%
# Drop rows with value missing in 3 or more of their columns
test_df.dropna(axis = 0, thresh = 3, inplace = True)

# reset index, because we droped some rows
test_df.reset_index(drop=True, inplace=True)

# %%
test_df.head()
# Out:
#   right  Demographics.Gender (0=Female, 1=Male)  Procedure_TKR.BMI  \
# 0     1                                     0.0              30.13
# 1     0                                     1.0              32.49
# 2     0                                     0.0              34.00
# 3     0                                     0.0              24.27
# 4     1                                     1.0              49.51
#
#    Procedure_TKR.Weight_kg  Procedure_TKR.Height_cm  Femur implanted  \
# 0                     95.3                    177.8             66.0
# 1                    100.2                    173.2             70.0
# 2                     98.4                    170.2             65.0
# 3                     62.1                    160.0             59.0
# 4                    161.0                    180.3             75.0
#
#    Tibia Implanted
# 0             74.0
# 1             77.0
# 2             74.0
# 3             64.0
# 4             80.0

# %%
test_df.isnull().sum()
# Out:
# right                                     0
# Demographics.Gender (0=Female, 1=Male)    0
# Procedure_TKR.BMI                         1
# Procedure_TKR.Weight_kg                   0
# Procedure_TKR.Height_cm                   0
# Femur implanted                           0
# Tibia Implanted                           3
# dtype: int64

# %%
# Drop any row with missing data
test_df.dropna(axis = 0, how = "any", inplace = True)

# reset index, because we droped some rows
test_df.reset_index(drop=True, inplace=True)

# %%
test_df.isnull().sum()
# Out:
# right                                     0
# Demographics.Gender (0=Female, 1=Male)    0
# Procedure_TKR.BMI                         0
# Procedure_TKR.Weight_kg                   0
# Procedure_TKR.Height_cm                   0
# Femur implanted                           0
# Tibia Implanted                           0
# dtype: int64

# %% [markdown]
# Our test data and train data have no missing value now.

# %%
test_df.shape
# Out:
# (485, 7)

# %% [markdown]
# <h3 id="correct_data_format">Correct data format</h3>
# <p>The last step in data cleaning is checking and making sure that all data is in the correct format (int, float, text or other).</p>
#
# In Pandas, we use:
#
# <p><b>.dtype()</b> to check the data type</p>
# <p><b>.astype()</b> to change the data type

# %% [markdown]
# Let's list the datatype of each column

# %%
# Check datatype of the variables in the train data
train_df.dtypes
# Out:
# Femur AP Dimension (mm)                   float64
# Tibia ML Dimension (mm)                   float64
# Demographics.Gender (0=Female, 1=Male)    float64
# Procedure_TKR.Height_cm                   float64
# Procedure_TKR.Weight_kg                   float64
# Procedure_TKR.BMI                         float64
# Surgery_Main.Side                          object
# dtype: object

# %% [markdown]
# All the variables in the train data are of the correct datatype.

# %%
# Check datatype of the variables in the test data
test_df.dtypes
# Out:
# right                                      object
# Demographics.Gender (0=Female, 1=Male)    float64
# Procedure_TKR.BMI                         float64
# Procedure_TKR.Weight_kg                   float64
# Procedure_TKR.Height_cm                   float64
# Femur implanted                           float64
# Tibia Implanted                           float64
# dtype: object

# %% [markdown]
# The feature "right" has been encoded to numeric variable, therefore we need to convert it to int

# %%
test_df[test_df["right"] == "1 and 0"]
# Out:
#       right  Demographics.Gender (0=Female, 1=Male)  Procedure_TKR.BMI  \
# 84  1 and 0                                     1.0             31.011
#
#     Procedure_TKR.Weight_kg  Procedure_TKR.Height_cm  Femur implanted  \
# 84                    106.6                    185.4             68.5
#
#     Tibia Implanted
# 84             74.0

# %% [markdown]
# The above observation will hinder datatype conversion. We can do away with the observation.

# %%
# Drop the conflicting observation
test_df.drop(test_df.index[(test_df["right"] == "1 and 0")], axis = 0, inplace = True)

# Reset the index after the row has been dropped
test_df.reset_index(drop=True, inplace=True)

# %%
# Convert the datatype of the column "right" to int datatype
test_df[["right"]] = test_df[["right"]].astype("int")

# Check the data type of the test dataset to ascertain that the conversion took place
test_df.dtypes
# Out:
# right                                       int32
# Demographics.Gender (0=Female, 1=Male)    float64
# Procedure_TKR.BMI                         float64
# Procedure_TKR.Weight_kg                   float64
# Procedure_TKR.Height_cm                   float64
# Femur implanted                           float64
# Tibia Implanted                           float64
# dtype: object

# %% [markdown]
# #### Encoding of Categorical Variables

# %% [markdown]
# The variable "Surgery_Main.Side" which has two outcomes, right and left can be encoded to numeric variable where 0 shall represent left and 1 shall represent right. We shall therefore rename the variable to "right" to match the name for the test data set.

# %%
train_df["Surgery_Main.Side"].value_counts()
# Out:
# Right    1740
# Left     1590
# Name: Surgery_Main.Side, dtype: int64

# %%
# Encode the variable and rename the variable
train_df["right"] = np.where(train_df["Surgery_Main.Side"].str.contains('Right'), 1, 0)

# Drop the variable 'Surgery_Main.Side'
train_df.drop("Surgery_Main.Side", axis = 1, inplace = True)

# Print the first five rows of the train dataset
train_df.head()
# Out:
#    Femur AP Dimension (mm)  Tibia ML Dimension (mm)  \
# 0                     60.4                     63.8
# 1                     53.5                     58.0
# 2                     57.5                     66.0
# 3                     65.3                     66.0
# 4                     60.8                     67.0
#
#    Demographics.Gender (0=Female, 1=Male)  Procedure_TKR.Height_cm  \
# 0                                     0.0                    60.00
# 1                                     0.0                   116.84
# 2                                     0.0                   127.00
# 3                                     0.0                   124.46
# 4                                     0.0                   121.92
#
#    Procedure_TKR.Weight_kg  Procedure_TKR.BMI  right
# 0                    58.64         162.888889      0
# 1                    62.20          45.562473      0
# 2                    52.00          32.240064      0
# 3                    68.64          44.311625      1
# 4                    75.00          50.455830      0

# %% [markdown]
# #### Renaming the columns

# %% [markdown]
# For the train dataset:
#
#
# * Femur AP Dimension (mm)&rarr; femur_dim
# * Tibia ML Dimension (mm)&rarr; tibia_dm
# * Demographics.Gender (0=Female, 1=Male)&rarr; gender
# * Procedure_TKR.Height_cm&rarr; height_cm
# * Procedure_TKR.Weight_kg&rarr; weight_kg
# * Procedure_TKR.BMI&rarr; bmi
# * Surgery_Main.Side&rarr; right
#
#
# For the test dataset:
#
#
# * right&rarr; right
# * Demographics.Gender (0=Female, 1=Male)&rarr; gender
# * Procedure_TKR.BMI&rarr; bmi
# * Procedure_TKR.Weight_kg&rarr; weight_kg
# * Procedure_TKR.Height_cm&rarr; height_cm
# * Femur implanted&rarr; femur_dim
# * Tibia Implanted&rarr; tibia_dim

# %%
# Renaming the train_df
train_df.rename(columns = {"Femur AP Dimension (mm)": "femur_dim", "Tibia ML Dimension (mm)": "tibia_dim",
                          "Demographics.Gender (0=Female, 1=Male)": "gender",
                           "Procedure_TKR.Height_cm": "height_cm",
                          "Procedure_TKR.Weight_kg": "weight_kg", "Procedure_TKR.BMI": "bmi", 
                           "Surgery_Main.Side": "right"}, inplace = True)

# Rounding off the bmi column to two decimal places
train_df["bmi"] = train_df["bmi"].round(2)

# Print the firstg 5 rows of the train dataset
train_df.head()
# Out:
#    femur_dim  tibia_dim  gender  height_cm  weight_kg     bmi  right
# 0       60.4       63.8     0.0      60.00      58.64  162.89      0
# 1       53.5       58.0     0.0     116.84      62.20   45.56      0
# 2       57.5       66.0     0.0     127.00      52.00   32.24      0
# 3       65.3       66.0     0.0     124.46      68.64   44.31      1
# 4       60.8       67.0     0.0     121.92      75.00   50.46      0

# %%
# Renaming the test_df
test_df.rename(columns = {"Femur implanted": "femur_dim", "Tibia Implanted": "tibia_dim",
                          "Demographics.Gender (0=Female, 1=Male)": "gender",
                           "Procedure_TKR.Height_cm": "height_cm",
                          "Procedure_TKR.Weight_kg": "weight_kg", "Procedure_TKR.BMI": "bmi"},
              inplace = True)

test_df.head()
# Out:
#    right  gender    bmi  weight_kg  height_cm  femur_dim  tibia_dim
# 0      1     0.0  30.13       95.3      177.8       66.0       74.0
# 1      0     1.0  32.49      100.2      173.2       70.0       77.0
# 2      0     0.0  34.00       98.4      170.2       65.0       74.0
# 3      0     0.0  24.27       62.1      160.0       59.0       64.0
# 4      1     1.0  49.51      161.0      180.3       75.0       80.0

# %%
# Save the clean train and test datasets as csv
train_df.to_csv("train_df_clean.csv", index = False)

# Save the test set as csv
test_df.to_csv("test_df_clean.csv", index = False)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### 1. Categorical Variables

# %%
# Loading the clean train dataset
train_df_clean = pd.read_csv("train_df_clean.csv")
train_df_clean.head()
# Out:
#    femur_dim  tibia_dim  gender  height_cm  weight_kg     bmi  right
# 0       60.4       63.8     0.0      60.00      58.64  162.89      0
# 1       53.5       58.0     0.0     116.84      62.20   45.56      0
# 2       57.5       66.0     0.0     127.00      52.00   32.24      0
# 3       65.3       66.0     0.0     124.46      68.64   44.31      1
# 4       60.8       67.0     0.0     121.92      75.00   50.46      0

# %%
# Loading the clean test dataset
test_df_clean = pd.read_csv("test_df_clean.csv")
test_df_clean.head()
# Out:
#    right  gender    bmi  weight_kg  height_cm  femur_dim  tibia_dim
# 0      1     0.0  30.13       95.3      177.8       66.0       74.0
# 1      0     1.0  32.49      100.2      173.2       70.0       77.0
# 2      0     0.0  34.00       98.4      170.2       65.0       74.0
# 3      0     0.0  24.27       62.1      160.0       59.0       64.0
# 4      1     1.0  49.51      161.0      180.3       75.0       80.0

# %%
# Check the count for each category in the gender column
plots = train_df_clean["gender"].value_counts().plot(kind = 'bar')
plt.title("Number of Patients per Gender")
plt.xlabel("Gender")
plt.ylabel("Number of Patients")

# Use xticks to change the x-axis labels
plt.xticks([0.0, 1.0], ['Female', 'Male'], rotation = 45)

# Iterating over the bars one-by-one
for bar in plots.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    plots.annotate(format(bar.get_height(), '.0f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha = 'center', va = 'center',
                   size = 15, xytext = (0, 10),
                   textcoords = 'offset points')
    
plt.ylim([0, 2500])    
plt.show();

# %%
# Check the count for each category in the gender column
plots = train_df_clean["right"].value_counts().plot(kind = 'bar')
plt.title("Number of Patients per Leg Side of Surgery")
plt.xlabel("Side of Surgery")
plt.ylabel("Number of Patients")

# Use xticks to change the x-axis labels
plt.xticks([0.0, 1.0], ['Right', 'Left'], rotation = 45)

# Iterating over the bars one-by-one
for bar in plots.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    plots.annotate(format(bar.get_height(), '.0f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha = 'center', va = 'center',
                   size = 15, xytext = (0, 10),
                   textcoords = 'offset points')
    
    
plt.ylim([0, 2000])    
plt.show();

# %% [markdown]
# ### 2. Continuous Variables

# %%
# Plot a histogram using the "height_cm" column
plt.figure(figsize = [8,5])
sns.histplot(data = train_df_clean, x = "height_cm", bins = 20, kde = True).set(title = "Distribution of Height (cm)", ylabel="Number of Patients")
plt.axvline(train_df_clean["height_cm"].mean(), color = 'k', linestyle = 'dashed', linewidth = 1)
min_ylim, max_ylim = plt.ylim()
plt.text(train_df_clean["height_cm"].mean()*1.1, max_ylim*0.9, 'Mean: {:.2f}'.format(train_df_clean["height_cm"].mean()))
plt.show();

# %%
# Plot a histogram using the "femur_dim" column
plt.figure(figsize = [8,5])
sns.histplot(data = train_df_clean, x = "femur_dim", bins = 20, kde = True).set(title = "Distribution of Femur Dimension (mm)", ylabel="Number of Patients")
plt.axvline(train_df_clean["femur_dim"].mean(), color = 'k', linestyle = 'dashed', linewidth = 1)
min_ylim, max_ylim = plt.ylim()
plt.text(train_df_clean["femur_dim"].mean()*1.1, max_ylim*0.9, 'Mean: {:.2f}'.format(train_df_clean['femur_dim'].mean()))
plt.show();

# %%
# Plot a histogram using the "tibia_dim" column
plt.figure(figsize = [8,5])
sns.histplot(data = train_df_clean, x = "tibia_dim", bins = 10, kde = True).set(title = "Distribution of Tibia Dimension (mm)", ylabel="Number of Patients")
plt.axvline(train_df_clean["tibia_dim"].mean(), color = 'k', linestyle = 'dashed', linewidth = 1)
min_ylim, max_ylim = plt.ylim()
plt.text(train_df_clean["tibia_dim"].mean()*1.1, max_ylim*0.9, 'Mean: {:.2f}'.format(train_df_clean["tibia_dim"].mean()))
plt.show();

# %%
# Plot a histogram using the "bmi" column
plt.figure(figsize = [8,5])
sns.histplot(data = train_df_clean, x = "bmi", bins = 20, kde = True).set(title = "Distribution of BMI", ylabel="Number of Patients")
plt.axvline(train_df_clean["bmi"].mean(), color = 'k', linestyle = 'dashed', linewidth = 1)
min_ylim, max_ylim = plt.ylim()
plt.text(train_df_clean["bmi"].mean()*1.1, max_ylim*0.9, 'Mean: {:.2f}'.format(train_df_clean["bmi"].mean()))
plt.show();

# %%
sns.swarmplot(x = train_df_clean['bmi'])
# Out:
# <AxesSubplot:xlabel='bmi'>

# %%
#Plot a histogram using the "weight_kg" column
plt.figure(figsize = [8,5])
sns.histplot(data = train_df_clean, 
             x = "weight_kg", bins = 30, kde = True).set(title = "Distribution of Weight (kg)", ylabel="Number of Patients")
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### 1. Categorical vs Categorical Variables

# %%
pd.crosstab(train_df_clean["gender"], train_df_clean["right"], margins = True)
# Out:
# right      0     1   All
# gender
# 0.0      988  1102  2090
# 1.0      602   638  1240
# All     1590  1740  3330

# %%
plt.figure(figsize = [8,5])
sns.heatmap(pd.crosstab(train_df_clean["gender"], train_df_clean["right"], margins = True), cmap = "YlGnBu");

# %% [markdown]
# ### 2. Categorical vs Continuous Variables

# %% [markdown]
# #### Gender vs Femur Dimension

# %%
#Plot two boxplots to compare dispersion
plt.figure(figsize = [8,5])
sns.boxplot(data = train_df_clean, x = 'gender', y = 'femur_dim')
plt.title("Distribution of Femur Dimension Per Gender")
plt.show()

# %% [markdown]
# Here we see that the distribution of femur dimension between the different gender categories differs. As such, gender could potentially be a predictor of femur dimension.

# %% [markdown]
# We will be using the t-test for independent samples. For the independent t-test, the following assumptions must be met.
#
# *   One independent, categorical variable with two levels or group
# *   One dependent continuous variable
# *   Independence of the observations. Each subject should belong to only one group. There is no relationship between the observations in each group.
# *   The dependent variable must follow a normal distribution
# *   Assumption of homogeneity of variance

# %% [markdown]
# State the hypothesis
#
# *   $H\_0: µ\_1 = µ\_2$ ("there is no difference in femur dimensions between male and females")
# *   $H\_1: µ\_1 ≠ µ\_2$ ("there is a difference in femur dimensions between male and females")

# %%
# Test for normality using the Shapiro-Wilk Test
from scipy.stats import shapiro
print(shapiro(train_df_clean[train_df_clean["gender"] == 1]["femur_dim"]))
print(shapiro(train_df_clean[train_df_clean["gender"] == 0]["femur_dim"]))
# Out:
# ShapiroResult(statistic=0.9793680906295776, pvalue=2.6178577534896608e-12)
# ShapiroResult(statistic=0.9760808348655701, pvalue=3.198656350339733e-18)

# %% [markdown]
# Since p-value < .05 in the two groups, we conclude that the dependent variable (femur_dim) is not normally distributed in the two gender groups. We therefore use Mann-Whitney U test instead of ttest for independence.

# %%
# Test for homogeneity of variance using levene's test
scipy.stats.levene(train_df_clean[train_df_clean["gender"] == 1]["femur_dim"],
                  train_df_clean[train_df_clean["gender"] == 0]["femur_dim"])
# Out:
# LeveneResult(statistic=53.67192469731021, pvalue=2.958271214764491e-13)

# %%
# Conduct the Mann-Whitney U Test
scipy.stats.mannwhitneyu(train_df_clean[train_df_clean["gender"] == 1]["femur_dim"],
                     train_df_clean[train_df_clean["gender"] == 0]["femur_dim"], alternative = 'two-sided')
# Out:
# MannwhitneyuResult(statistic=2303444.5, pvalue=8.39081468193575e-310)

# %% [markdown]
# Since the p-value < 0.05, we reject the null hypothesis and conclude that the Femur dimensions of the two gender groups is significantly different from each other.
# * Gender is therefore a significant predictor of femur dimension.

# %% [markdown]
# #### Gender vs Tibia Dimension

# %%
# Plot two boxplots to compare dispersion
plt.figure(figsize = [8,5])
sns.boxplot(data = train_df_clean, x = 'gender', y ='tibia_dim')
plt.title("Distribution of Tibia Dimension Per Gender")
plt.show()

# %% [markdown]
# State the hypothesis
#
# *   $H\_0: µ\_1 = µ\_2$ ("there is no difference in tibia dimensions between male and females")
# *   $H\_1: µ\_1 ≠ µ\_2$ ("there is a difference in tibia dimensions between male and females")

# %%
# Test for normality using the Shapiro-Wilk Test
from scipy.stats import shapiro
print(shapiro(train_df_clean[train_df_clean["gender"] == 1]["tibia_dim"]))
print(shapiro(train_df_clean[train_df_clean["gender"] == 0]["tibia_dim"]))
# Out:
# ShapiroResult(statistic=0.9047033786773682, pvalue=4.046644206303919e-27)
# ShapiroResult(statistic=0.8502253293991089, pvalue=1.170854931866601e-40)

# %% [markdown]
# Since p-value < .05 in the two groups, we conclude that the dependent variable (tibia_dim) is not normally distributed in the two gender groups. We therefore use Mann-Whitney U test instead of ttest for independence

# %%
# Conduct the Mann-Whitney U Test
scipy.stats.mannwhitneyu(train_df_clean[train_df_clean["gender"] == 1]["tibia_dim"],
                     train_df_clean[train_df_clean["gender"] == 0]["tibia_dim"], alternative = 'two-sided')
# Out:
# MannwhitneyuResult(statistic=2382318.0, pvalue=0.0)

# %% [markdown]
# Since the p-value < 0.05, we reject the null hypothesis and conclude that the tibia dimensions of the two gender groups is significantly different from each other.
# * Gender is therefore a significant predictor of tibia dimension.

# %% [markdown]
# #### Side of Surgery vs Femur Dimension

# %%
#Plot two boxplots to compare dispersion
plt.figure(figsize = [8,5])
sns.boxplot(data = train_df_clean, x = 'right', y = 'femur_dim')
plt.title("Distribution of Femur Dimension Per Side of Surgery")
plt.show()

# %% [markdown]
# State the hypothesis
#
# *   $H\_0: µ\_1 = µ\_2$ ("there is no difference in Femur dimension between Left and Right Side of Surgery")
# *   $H\_1: µ\_1 ≠ µ\_2$ ("there is a difference in Femur dimension between Left and Right Side of Surgery")

# %%
# Test for normality using the Shapiro-Wilk Test
from scipy.stats import shapiro
print(shapiro(train_df_clean[train_df_clean["right"] == 1]["femur_dim"]))
print(shapiro(train_df_clean[train_df_clean["right"] == 0]["femur_dim"]))
# Out:
# ShapiroResult(statistic=0.9713935256004333, pvalue=4.059048471281918e-18)
# ShapiroResult(statistic=0.9767559766769409, pvalue=2.288012173386894e-15)

# %% [markdown]
# Since p-value < .05 in the two groups, we conclude that the dependent variable (femur_dim) is not normally distributed in the two groups. We therefore use Mann-Whitney U test instead of ttest for independence.

# %%
# Conduct the Mann-Whitney U Test
scipy.stats.mannwhitneyu(train_df_clean[train_df_clean["right"] == 1]["femur_dim"],
                     train_df_clean[train_df_clean["right"] == 0]["femur_dim"], alternative = 'two-sided')
# Out:
# MannwhitneyuResult(statistic=1318408.0, pvalue=0.019020170155070737)

# %% [markdown]
# Since the p-value > 0.01, we fail to reject the null hypothesis and conclude that the femur dimensions of the two groups is not significantly different from each other.
# * Side of Surgery is therefore a not significant predictor of femur dimension.

# %% [markdown]
# #### Side of Surgery vs Tibia Dimension

# %%
# Plot two boxplots to compare dispersion
plt.figure(figsize = [8,5])
sns.boxplot(data = train_df_clean, x = 'right', y ='tibia_dim')
plt.title("Distribution of Tibia Dimension Per Side of Surgery")
plt.show()

# %% [markdown]
# State the hypothesis
#
# *   $H\_0: µ\_1 = µ\_2$ ("there is no difference in Tibia dimension between Left and Right Side of Surgery")
# *   $H\_1: µ\_1 ≠ µ\_2$ ("there is a difference in Tibia dimension between Left and Right Side of Surgery")

# %%
# Test for normality using the Shapiro-Wilk Test
from scipy.stats import shapiro
print(shapiro(train_df_clean[train_df_clean["right"] == 1]["tibia_dim"]))
print(shapiro(train_df_clean[train_df_clean["right"] == 0]["tibia_dim"]))
# Out:
# ShapiroResult(statistic=0.9179987907409668, pvalue=9.994751120295929e-30)
# ShapiroResult(statistic=0.9174461364746094, pvalue=1.301720280859913e-28)

# %% [markdown]
# Since p-value < .05 in the two groups, we conclude that the dependent variable (tibia_dim) is not normally distributed in the two groups. We therefore use Mann-Whitney U test instead of ttest for independence.

# %%
# Conduct the Mann-Whitney U Test
scipy.stats.mannwhitneyu(train_df_clean[train_df_clean["right"] == 1]["tibia_dim"],
                     train_df_clean[train_df_clean["right"] == 0]["tibia_dim"], alternative = 'two-sided')
# Out:
# MannwhitneyuResult(statistic=1364677.0, pvalue=0.4956632011481117)

# %% [markdown]
# Since the p-value > 0.05, we fail to reject the null hypothesis and conclude that the tibia dimensions of the two groups is not significantly different from each other.
# * Side of Surgery is therefore a not significant predictor of tibia dimension.

# %% [markdown]
# ### 3. Continuous vs Continuous Variables

# %% [markdown]
# #### Height vs Femur Dimension

# %%
# Relationship between Height and Femur Dimension
plt.figure(figsize = [8,5])
sns.scatterplot(data = train_df_clean, x = 'height_cm', y = 'femur_dim', palette = 'colorblind')
plt.title("Relationship between Height and Femur Dimension")
plt.xlabel("Height (cm)")
plt.ylabel("Femur Dimension (mm)")
plt.show();

# %%
train_df_clean[['height_cm', 'femur_dim']].corr()
# Out:
#            height_cm  femur_dim
# height_cm   1.000000   0.611528
# femur_dim   0.611528   1.000000

# %% [markdown]
# State the hypothesis:
#
# *   $H\_0:$ Femur Dimension is not correlated with Height
# *   $H\_1:$ Femur Dimension is correlated with Height

# %%
# Perform a correlation test using a Pearson Correlation Test
scipy.stats.pearsonr(train_df_clean['height_cm'], train_df_clean['femur_dim'])
# Out:
# (0.6115278123377907, 0.0)

# %% [markdown]
# **Conclusion:** Since the p-value  (Sig. (2-tailed)  < 0.05, we reject  the Null hypothesis and conclude that there  exists a relationship between height and femur dimension.
#
# * Height is therefore a significant predictor of Femur Dimension.

# %% [markdown]
# #### Height vs Tibia Dimension

# %%
# Relationship between Height and Tibia Dimension
plt.figure(figsize = [8,5])
sns.scatterplot(data = train_df_clean, x = 'height_cm', y = 'tibia_dim', palette = 'colorblind')
plt.title("Relationship between Height and Tibia Dimension")
plt.xlabel("Height (cm)")
plt.ylabel("Tibia Dimension (mm)")
plt.show();

# %%
train_df_clean[['height_cm', 'tibia_dim']].corr()
# Out:
#            height_cm  tibia_dim
# height_cm   1.000000   0.609881
# tibia_dim   0.609881   1.000000

# %% [markdown]
# State the hypothesis:
#
# *   $H\_0:$ Tibia Dimension is not correlated with Height
# *   $H\_1:$ Tibia Dimension is correlated with Height

# %%
# Perform a correlation test using a Pearson Correlation Test
scipy.stats.pearsonr(train_df_clean['height_cm'], train_df_clean['tibia_dim'])
# Out:
# (0.6098808129430573, 0.0)

# %% [markdown]
# **Conclusion:** Since the p-value  (Sig. (2-tailed)  < 0.05, we reject  the Null hypothesis and conclude that there  exists a relationship between height and tibia dimension.
#
# * Height is therefore a significant predictor of Tibia Dimension.

# %% [markdown]
# #### Weight vs Femur Dimension

# %%
# Relationship between Weight and Femur Dimension
plt.figure(figsize = [8,5])
sns.scatterplot(data = train_df_clean, x = 'weight_kg', y = 'femur_dim', palette = 'colorblind')
plt.title("Relationship between Weight and Femur Dimension")
plt.xlabel("Weight (kg)")
plt.ylabel("Femur Dimension (mm)")
plt.show();

# %%
train_df_clean[['weight_kg', 'femur_dim']].corr()
# Out:
#            weight_kg  femur_dim
# weight_kg   1.000000   0.310713
# femur_dim   0.310713   1.000000

# %% [markdown]
# State the hypothesis:
#
# *   $H\_0:$ Femur Dimension is not correlated with Weight
# *   $H\_1:$ Femur Dimension is correlated with Weight

# %%
# Perform a correlation test using a Pearson Correlation Test
scipy.stats.pearsonr(train_df_clean['weight_kg'], train_df_clean['femur_dim'])
# Out:
# (0.31071284494892015, 1.8955075119889115e-75)

# %% [markdown]
# **Conclusion:** Since the p-value  (Sig. (2-tailed)  < 0.05, we reject  the Null hypothesis and conclude that there  exists a relationship between weight and femur dimension.
#
# * Weight is therefore a signifanct predictor of Femur Dimension.

# %% [markdown]
# #### Weight vs Tibia Dimension

# %%
# Relationship between Weight and Femur Dimension
plt.figure(figsize = [8,5])
sns.scatterplot(data = train_df_clean, x = 'weight_kg', y = 'tibia_dim', palette = 'colorblind')
plt.title("Relationship between Weight and Tibia Dimension")
plt.xlabel("Weight (kg)")
plt.ylabel("Tibia Dimension (mm)")
plt.show();

# %%
train_df_clean[['weight_kg', 'tibia_dim']].corr()
# Out:
#            weight_kg  tibia_dim
# weight_kg   1.000000   0.338094
# tibia_dim   0.338094   1.000000

# %% [markdown]
# State the hypothesis:
#
# *   $H\_0:$ Tibia Dimension is not correlated with Weight
# *   $H\_1:$ Tibia Dimension is correlated with Weight

# %%
# Perform a correlation test using a Pearson Correlation Test
scipy.stats.pearsonr(train_df_clean['weight_kg'], train_df_clean['tibia_dim'])
# Out:
# (0.3380937087302778, 7.757983063805961e-90)

# %% [markdown]
# **Conclusion:** Since the p-value  (Sig. (2-tailed)  < 0.05, we reject  the Null hypothesis and conclude that there  exists a relationship between weight and tibia dimension.
#
# * Weight is therefore a significant predictor of Tibia Dimension.

# %% [markdown]
# #### BMI vs Femur Dimension

# %%
# Relationship between BMI and Femur Dimension
plt.figure(figsize = [8,5])
sns.scatterplot(data = train_df_clean, x = 'bmi', y = 'femur_dim')
plt.title("Relationship between BMI and Femur Dimension")
plt.xlabel("BMI")
plt.ylabel("Femur Dimension (mm)")
plt.show();

# %%
train_df_clean[['bmi', 'femur_dim']].corr()
# Out:
#                 bmi  femur_dim
# bmi        1.000000  -0.034908
# femur_dim -0.034908   1.000000

# %% [markdown]
# State the hypothesis:
#
# *   $H\_0:$ Femur Dimension is not correlated with BMI
# *   $H\_1:$ Femur Dimension is correlated with BMI

# %%
# Perform a correlation test using a Pearson Correlation Test
scipy.stats.pearsonr(train_df_clean['bmi'], train_df_clean['femur_dim'])
# Out:
# (-0.03490775997474448, 0.04398328458338386)

# %% [markdown]
# **Conclusion:** Since the p-value  (Sig. (2-tailed)  < 0.05, we reject the Null hypothesis and conclude that there  exists a relationship between bmi and femur dimension.
# Reducing our alpha level to 1%, we fail to reject the Null hypothesis and conclude that there is no correlation between bmi and femur dimension.
#
# * BMI is therefore not a significant predictor of Femur Dimension.

# %% [markdown]
# #### BMI vs Tibia Dimension

# %%
# Relationship between BMI and Tibia Dimension
plt.figure(figsize = [8,5])
sns.scatterplot(data = train_df_clean, x = 'bmi', y = 'tibia_dim', palette = 'colorblind')
plt.title("Relationship between BMI and Tibia Dimension")
plt.xlabel("BMI")
plt.ylabel("Tibia Dimension (mm)")
plt.show();

# %%
train_df_clean[['bmi', 'tibia_dim']].corr()
# Out:
#                 bmi  tibia_dim
# bmi        1.000000  -0.012401
# tibia_dim -0.012401   1.000000

# %% [markdown]
# State the hypothesis:
#
# *   $H\_0:$ Tibia Dimension is not correlated with BMI
# *   $H\_1:$ Tibia Dimension is correlated with BMI

# %%
# Perform a correlation test using a Pearson Correlation Test
scipy.stats.pearsonr(train_df_clean['bmi'], train_df_clean['tibia_dim'])
# Out:
# (-0.01240133876486808, 0.4743666246207884)

# %% [markdown]
# **Conclusion:** Since the p-value  (Sig. (2-tailed)  > 0.05, we reject the Null hypothesis and conclude that there is no relationship between bmi and tibia dimension.
#
# * BMI is therefore not a significant predictor of Tibia Dimension.

# %% [markdown]
# ## Multivariate Analysis

# %%
# Relationship between Height and Femur Dimension
plt.figure(figsize = [8,5])
sns.scatterplot(data = train_df_clean, x = 'height_cm', y = 'femur_dim', hue = 'gender')
plt.title("Relationship between Height and Femur Dimension")
plt.xlabel("Height (cm)")
plt.ylabel("Femur Dimension (mm)")
plt.show();

# %%
# Relationship between Height and Tibia Dimension
plt.figure(figsize = [8,5])
sns.scatterplot(data = train_df_clean, x = 'height_cm', y = 'tibia_dim', hue = 'gender')
plt.title("Relationship between Height and Tibia Dimension")
plt.xlabel("Height (cm)")
plt.ylabel("Tibia Dimension (mm)")
plt.show();

# %%
# Relationship between Weight and Femur Dimension
plt.figure(figsize = [8,5])
sns.scatterplot(data = train_df_clean, x = 'weight_kg', y = 'femur_dim', hue = 'gender')
plt.title("Relationship between Weight and Femur Dimension")
plt.xlabel("Weight (kg)")
plt.ylabel("Femur Dimension (mm)")
plt.show();

# %%
# Relationship between Weight and Femur Dimension
plt.figure(figsize = [8,5])
sns.scatterplot(data = train_df_clean, x = 'weight_kg', y = 'tibia_dim', hue = 'gender')
plt.title("Relationship between Weight and Tibia Dimension")
plt.xlabel("Weight (kg)")
plt.ylabel("Tibia Dimension (mm)")
plt.show();

# %%
# Relationship between BMI and Femur Dimension
plt.figure(figsize = [8,5])
sns.scatterplot(data = train_df_clean, x = 'bmi', y = 'femur_dim', hue = 'gender')
plt.title("Relationship between BMI and Femur Dimension")
plt.xlabel("BMI")
plt.ylabel("Femur Dimension (mm)")
plt.show();

# %%
# Relationship between BMI and Tibia Dimension
plt.figure(figsize = [8,5])
sns.scatterplot(data = train_df_clean, x = 'bmi', y = 'tibia_dim', hue = 'gender')
plt.title("Relationship between BMI and Tibia Dimension")
plt.xlabel("BMI")
plt.ylabel("Tibia Dimension (mm)")
plt.show();

# %%
# Checking correlation between numeric variables
numeric_df = train_df_clean[['femur_dim', 'tibia_dim', 'height_cm', 'weight_kg', 'bmi']]
numeric_df.head()
# Out:
#    femur_dim  tibia_dim  height_cm  weight_kg     bmi
# 0       60.4       63.8      60.00      58.64  162.89
# 1       53.5       58.0     116.84      62.20   45.56
# 2       57.5       66.0     127.00      52.00   32.24
# 3       65.3       66.0     124.46      68.64   44.31
# 4       60.8       67.0     121.92      75.00   50.46

# %%
# Creating a correlation matrix
corr_mat = numeric_df.corr()
corr_mat
# Out:
#            femur_dim  tibia_dim  height_cm  weight_kg       bmi
# femur_dim   1.000000   0.804997   0.611528   0.310713 -0.034908
# tibia_dim   0.804997   1.000000   0.609881   0.338094 -0.012401
# height_cm   0.611528   0.609881   1.000000   0.179064 -0.525913
# weight_kg   0.310713   0.338094   0.179064   1.000000  0.502559
# bmi        -0.034908  -0.012401  -0.525913   0.502559  1.000000

# %%
# Plotting the correlation matrix using a heatmap
plt.figure(figsize = [8,5])
sns.heatmap(corr_mat, cmap = 'YlGnBu', annot = True)
plt.show();

# %% [markdown]
# ### Significant Features / Predictors

# %% [markdown]
# #### Numerical Predictors

# %% [markdown]
# 1. height_cm
# 2. weight_kg

# %% [markdown]
# #### Categorical Predictors

# %% [markdown]
# 1. gender

# %% [markdown]
# # Model Development
